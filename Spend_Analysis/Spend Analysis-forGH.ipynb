# %% [markdown]
# # Spend Analysis
# Prepared by: Nickolas K. Freeman, Ph.D.
#
# From Wikipedia (accessed 1/27/2020):
#
# > Spend Analysis is the process of collecting, cleansing, classifying and analyzing expenditure data with the purpose of decreasing procurement costs, improving efficiency, and monitoring controls and compliance. It can also be leveraged in other areas of business such as inventory management, contract management, complex sourcing, supplier management, budgeting, planning, and product development.
# >
# > There are three core areas of spend analysis - visibility, analysis, and process. By leveraging all three, companies can generate answers to the crucial questions affecting their spending, including:
# >
# > - What am I really spending?
# > - With whom am I spending it?
# > - Am I getting what was promised for that spend?
# > Spend analysis is often viewed as part of a larger domain known as spend management which incorporates spend analysis, commodity management and strategic sourcing.
# >
# > Companies perform a spend analysis for several reasons. The core business driver for most organizations is profitability. In addition to improving compliance and reducing cycle times, performing detailed spend analysis helps companies find new areas of savings that previously went untapped, and hold on to past areas of savings that they have already negotiated.
#
# In this notebook, we will use U.S. government data on contract spending available from https://usaspending.org to analyze FY 2019 expenditures in the state of Alabama. In particular, we will investigate:
# - Which products and services are being purchased?
# - Who is purchasing these products or services?
# - From whom are the products or services being purchased?
# - How are these products or services being purchased?

# %% [markdown]
# ## Working with Excel Data in Python via Pandas
#
# The data available at https://usaspending.org is provided using a *comma-separated value* format. By default, most machines that have Microsoft Office installed will open such files with Excel by default. We will use the `pandas` library to work with the data. We will also use the `os` library, part of python's standard library, to inspect files on our machine. the following code block imports the two libraries. Notices that we use the `as` import method with pandas so that we can give the library and alias (of `pd`).

# %%
import os

import pandas as pd

# %% [markdown]
# The following code block sets some options for pandas. In particular, we specify 1) that we want to display 40 columns of any imported data and 2) that we want to display floating point data with up to four decimal points.

# %%
# Specify maximum columns = 40
pd.set_option('display.max_columns', 40)

# Specify floating-point precision
pd.set_option('display.float_format', '{:.4f}'.format)

# %% [markdown]
# The following code block uses the `listdir` function in the `os` library to generate a list of files in the current directory (the directory where the `.ipynb` file is located).

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'al_contracts_prime_transactions_FY2019.csv',
#  'AL_FY2019.csv',
#  'ct_contracts_prime_transactions_FY2019.csv',
#  'CT_FY2019.csv',
#  'de_contracts_prime_transactions_FY2019.csv',
#  'DE_FY2019.csv',
#  'File Prep.ipynb',
#  'info_al_contracts_prime_transactions_FY2019.csv',
#  'info_ct_contracts_prime_transactions_FY2019.csv',
#  'info_de_contracts_prime_transactions_FY2019.csv',
#  'info_tn_contracts_prime_transactions_FY2019.csv',
#  'outputs',
#  'Spend Analysis.ipynb',
#  'tn_contracts_prime_transactions_FY2019.csv',
#  'TN_FY2019.csv']

# %% [markdown]
# We will be working with the `AL_FY2019.csv` file. The following code block reads the file using pandas and stores the data in an variable named `data`.

# %%
data = pd.read_csv('AL_FY2019.csv')

# %% [markdown]
# The following code block shows how we can check the `type` of a variable or object. In python, different types will have differnt `methods` and `attributes` available. Thus, it is important to understand the type of variable or object you are dealing with so that you know what options are available.

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# The previous code block shows that the `data` variable is actually a panda's `DataFrame`. DataFrames have a `head` method that prints the first five rows of data, by default.

# %%
data.head()
# Out:
#        award_id_piid     parent_award_agency_name parent_award_id  \
# 0      80NSSC17F0945  FEDERAL ACQUISITION SERVICE      GS00F0004X
# 1  HHSM500201700003B  FEDERAL ACQUISITION SERVICE      GS23F0002X
# 2      47QRAA18D00BC                          NaN             NaN
# 3         GS07F0304W                          NaN             NaN
# 4         GS35F203DA                          NaN             NaN
#
#    total_dollars_obligated  current_total_value_of_award  \
# 0              109775.1200                   109775.1200
# 1                   0.0000                           nan
# 2                   0.0000                           nan
# 3                   0.0000                           nan
# 4                   0.0000                           nan
#
#    potential_total_value_of_award action_date  \
# 0                     109775.1200  2019-04-24
# 1                   45000000.0000  2018-10-01
# 2                    1000000.0000  2018-10-02
# 3                     250000.0000  2018-10-01
# 4                     700000.0000  2018-10-01
#
#                                 awarding_agency_name  \
# 0  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 1      DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)
# 2              GENERAL SERVICES ADMINISTRATION (GSA)
# 3              GENERAL SERVICES ADMINISTRATION (GSA)
# 4              GENERAL SERVICES ADMINISTRATION (GSA)
#
#                         awarding_sub_agency_name  \
# 0  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 1     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 2                    FEDERAL ACQUISITION SERVICE
# 3                    FEDERAL ACQUISITION SERVICE
# 4                    FEDERAL ACQUISITION SERVICE
#
#                   awarding_office_name  funding_agency_code  \
# 0          NASA SHARED SERVICES CENTER                   80
# 1   OFC OF ACQUISITION AND GRANTS MGMT                   75
# 2    GSA/FAS/PSHC/PROF SRVCS SCHED-PSS                   47
# 3     GSA/FAS SCIENTFC,TEMP SVCS,ADINT                   47
# 4  GSA/FAS CENTER FOR IT SCHEDULE PROG                   47
#
#                                  funding_agency_name  \
# 0  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 1      DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)
# 2              GENERAL SERVICES ADMINISTRATION (GSA)
# 3              GENERAL SERVICES ADMINISTRATION (GSA)
# 4              GENERAL SERVICES ADMINISTRATION (GSA)
#
#                          funding_sub_agency_name  \
# 0  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 1     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 2                    FEDERAL ACQUISITION SERVICE
# 3                    FEDERAL ACQUISITION SERVICE
# 4                    FEDERAL ACQUISITION SERVICE
#
#                    funding_office_name  recipient_duns  \
# 0          NASA SHARED SERVICES CENTER       618735948
# 1   OFC OF ACQUISITION AND GRANTS MGMT       133312947
# 2    GSA/FAS/PSHC/PROF SRVCS SCHED-PSS        17447275
# 3     GSA/FAS SCIENTFC,TEMP SVCS,ADINT        50983451
# 4  GSA/FAS CENTER FOR IT SCHEDULE PROG       196147391
#
#                                recipient_name  \
# 0                            TEC-MASTERS INC.
# 1         CAHABA SAFEGUARD ADMINISTRATORS LLC
# 2                           LSINC CORPORATION
# 3  NORTH AMERICA FIRE EQUIPMENT COMPANY, INC.
# 4                 GLOBAL TEL*LINK CORPORATION
#
#                         recipient_parent_name  recipient_parent_duns  \
# 0                            TEC-MASTERS INC.         618735948.0000
# 1         BLUE CROSS & BLUE SHIELD OF ALABAMA          63689954.0000
# 2                                   LSINC LLC          17447275.0000
# 3  NORTH AMERICA FIRE EQUIPMENT COMPANY  INC.          50983451.0000
# 4                 GLOBAL TEL LINK CORPORATION         968416219.0000
#
#   recipient_country_code recipient_city_name  ...  \
# 0                    USA          HUNTSVILLE  ...
# 1                    USA          BIRMINGHAM  ...
# 2                    USA          HUNTSVILLE  ...
# 3                    USA             DECATUR  ...
# 4                    USA              MOBILE  ...
#
#   primary_place_of_performance_state_code award_or_idv_flag      award_type  \
# 0                                      AL             AWARD  DELIVERY ORDER
# 1                                     NaN               IDV             NaN
# 2                                     NaN               IDV             NaN
# 3                                     NaN               IDV             NaN
# 4                                     NaN               IDV             NaN
#
#   type_of_contract_pricing_code  \
# 0                             J
# 1                             1
# 2                             J
# 3                             K
# 4                             J
#
#                             type_of_contract_pricing  \
# 0                                   FIRM FIXED PRICE
# 1  ORDER DEPENDENT (IDV ALLOWS PRICING ARRANGEMEN...
# 2                                   FIRM FIXED PRICE
# 3         FIXED PRICE WITH ECONOMIC PRICE ADJUSTMENT
# 4                                   FIRM FIXED PRICE
#
#                  product_or_service_code_description  naics_code  \
# 0       SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL 541712.0000
# 1                       SUPPORT- PROFESSIONAL: OTHER 541611.0000
# 2  SUPPORT- PROFESSIONAL: MARKET RESEARCH/PUBLIC ... 541330.0000
# 3                            FIRE FIGHTING EQUIPMENT 315992.0000
# 4    IT AND TELECOM- OTHER IT AND TELECOMMUNICATIONS 541512.0000
#
#                                    naics_description  \
# 0  RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...
# 1  ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...
# 2                               ENGINEERING SERVICES
# 3                     GLOVE AND MITTEN MANUFACTURING
# 4                   COMPUTER SYSTEMS DESIGN SERVICES
#
#   domestic_or_foreign_entity country_of_product_or_service_origin_code  \
# 0        U.S. OWNED BUSINESS                                       USA
# 1        U.S. OWNED BUSINESS                                       NaN
# 2        U.S. OWNED BUSINESS                                       NaN
# 3        U.S. OWNED BUSINESS                                       NaN
# 4        U.S. OWNED BUSINESS                                       NaN
#
#              place_of_manufacture            extent_competed  \
# 0  NOT A MANUFACTURED END PRODUCT  FULL AND OPEN COMPETITION
# 1                             NaN  FULL AND OPEN COMPETITION
# 2                             NaN  FULL AND OPEN COMPETITION
# 3                             NaN  FULL AND OPEN COMPETITION
# 4                             NaN  FULL AND OPEN COMPETITION
#
#                       solicitation_procedures veteran_owned_business  \
# 0  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY                      f
# 1  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY                      f
# 2                   NEGOTIATED PROPOSAL/QUOTE                      f
# 3                   NEGOTIATED PROPOSAL/QUOTE                      f
# 4                   NEGOTIATED PROPOSAL/QUOTE                      f
#
#   woman_owned_business minority_owned_business       organizational_type  \
# 0                    f                       t  CORPORATE NOT TAX EXEMPT
# 1                    f                       f                     OTHER
# 2                    t                       f  CORPORATE NOT TAX EXEMPT
# 3                    f                       f  CORPORATE NOT TAX EXEMPT
# 4                    f                       f  CORPORATE NOT TAX EXEMPT
#
#   for_profit_organization nonprofit_organization awarding_agency_abbr
# 0                       t                      f                 NASA
# 1                       t                      f                  HHS
# 2                       t                      f                  GSA
# 3                       t                      f                  GSA
# 4                       t                      f                  GSA
#
# [5 rows x 44 columns]

# %% [markdown]
# We can get more or less rows to print by supplying the optional argument `n`.

# %%
data.head(n = 10) # or just data.head(10)
# Out:
#        award_id_piid                   parent_award_agency_name  \
# 0      80NSSC17F0945                FEDERAL ACQUISITION SERVICE
# 1  HHSM500201700003B                FEDERAL ACQUISITION SERVICE
# 2      47QRAA18D00BC                                        NaN
# 3         GS07F0304W                                        NaN
# 4         GS35F203DA                                        NaN
# 5      36C78618D0199                                        NaN
# 6      AG4740C170023                                        NaN
# 7         NNM16AA27C                                        NaN
# 8  15B61919FUB110010  FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 9  15B61919FUB210001  FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
#
#     parent_award_id  total_dollars_obligated  current_total_value_of_award  \
# 0        GS00F0004X              109775.1200                   109775.1200
# 1        GS23F0002X                   0.0000                           nan
# 2               NaN                   0.0000                           nan
# 3               NaN                   0.0000                           nan
# 4               NaN                   0.0000                           nan
# 5               NaN                   0.0000                           nan
# 6               NaN                   0.0000                           nan
# 7               NaN             3877805.0000                           nan
# 8  DJBP0619BPA14008                2400.0000                     2400.0000
# 9  DJBP0619BPA14008               50000.0000                    50000.0000
#
#    potential_total_value_of_award action_date  \
# 0                     109775.1200  2019-04-24
# 1                   45000000.0000  2018-10-01
# 2                    1000000.0000  2018-10-02
# 3                     250000.0000  2018-10-01
# 4                     700000.0000  2018-10-01
# 5                     835768.9300  2018-10-01
# 6                     309825.0000  2018-10-02
# 7                    5274465.0000  2018-10-01
# 8                       2400.0000  2018-10-02
# 9                      50000.0000  2018-10-02
#
#                                 awarding_agency_name  \
# 0  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 1      DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)
# 2              GENERAL SERVICES ADMINISTRATION (GSA)
# 3              GENERAL SERVICES ADMINISTRATION (GSA)
# 4              GENERAL SERVICES ADMINISTRATION (GSA)
# 5                DEPARTMENT OF VETERANS AFFAIRS (VA)
# 6                   DEPARTMENT OF AGRICULTURE (USDA)
# 7  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 8                        DEPARTMENT OF JUSTICE (DOJ)
# 9                        DEPARTMENT OF JUSTICE (DOJ)
#
#                         awarding_sub_agency_name  \
# 0  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 1     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 2                    FEDERAL ACQUISITION SERVICE
# 3                    FEDERAL ACQUISITION SERVICE
# 4                    FEDERAL ACQUISITION SERVICE
# 5                VETERANS AFFAIRS, DEPARTMENT OF
# 6                 AGRICULTURAL MARKETING SERVICE
# 7  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 8      FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 9      FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
#
#                   awarding_office_name  funding_agency_code  \
# 0          NASA SHARED SERVICES CENTER                   80
# 1   OFC OF ACQUISITION AND GRANTS MGMT                   75
# 2    GSA/FAS/PSHC/PROF SRVCS SCHED-PSS                   47
# 3     GSA/FAS SCIENTFC,TEMP SVCS,ADINT                   47
# 4  GSA/FAS CENTER FOR IT SCHEDULE PROG                   47
# 5      NATIONAL CEMETERY ADMIN (00786)                   36
# 6           USDA  AMS  COTTON DIVISION                   12
# 7    NASA MARSHALL SPACE FLIGHT CENTER                   80
# 8    DEPT OF JUSTICE BUREAU OF PRISONS                   15
# 9    DEPT OF JUSTICE BUREAU OF PRISONS                   15
#
#                                  funding_agency_name  \
# 0  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 1      DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)
# 2              GENERAL SERVICES ADMINISTRATION (GSA)
# 3              GENERAL SERVICES ADMINISTRATION (GSA)
# 4              GENERAL SERVICES ADMINISTRATION (GSA)
# 5                DEPARTMENT OF VETERANS AFFAIRS (VA)
# 6                   DEPARTMENT OF AGRICULTURE (USDA)
# 7  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 8                        DEPARTMENT OF JUSTICE (DOJ)
# 9                        DEPARTMENT OF JUSTICE (DOJ)
#
#                          funding_sub_agency_name  \
# 0  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 1     CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 2                    FEDERAL ACQUISITION SERVICE
# 3                    FEDERAL ACQUISITION SERVICE
# 4                    FEDERAL ACQUISITION SERVICE
# 5                VETERANS AFFAIRS, DEPARTMENT OF
# 6                 AGRICULTURAL MARKETING SERVICE
# 7  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 8      FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 9      FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
#
#                    funding_office_name  recipient_duns  \
# 0          NASA SHARED SERVICES CENTER       618735948
# 1   OFC OF ACQUISITION AND GRANTS MGMT       133312947
# 2    GSA/FAS/PSHC/PROF SRVCS SCHED-PSS        17447275
# 3     GSA/FAS SCIENTFC,TEMP SVCS,ADINT        50983451
# 4  GSA/FAS CENTER FOR IT SCHEDULE PROG       196147391
# 5      NATIONAL CEMETERY ADMIN (00786)        79823797
# 6           USDA  AMS  COTTON DIVISION       166767959
# 7    NASA MARSHALL SPACE FLIGHT CENTER       805721268
# 8    DEPT OF JUSTICE BUREAU OF PRISONS         4677399
# 9    DEPT OF JUSTICE BUREAU OF PRISONS         4677399
#
#                                recipient_name  \
# 0                            TEC-MASTERS INC.
# 1         CAHABA SAFEGUARD ADMINISTRATORS LLC
# 2                           LSINC CORPORATION
# 3  NORTH AMERICA FIRE EQUIPMENT COMPANY, INC.
# 4                 GLOBAL TEL*LINK CORPORATION
# 5               AWARD COMPANY OF AMERICA, LLC
# 6                               PHELPS, COMER
# 7                         AETOS SYSTEMS, INC.
# 8                              NAPHCARE, INC.
# 9                              NAPHCARE, INC.
#
#                         recipient_parent_name  recipient_parent_duns  \
# 0                            TEC-MASTERS INC.         618735948.0000
# 1         BLUE CROSS & BLUE SHIELD OF ALABAMA          63689954.0000
# 2                                   LSINC LLC          17447275.0000
# 3  NORTH AMERICA FIRE EQUIPMENT COMPANY  INC.          50983451.0000
# 4                 GLOBAL TEL LINK CORPORATION         968416219.0000
# 5               AWARD COMPANY OF AMERICA  LLC          79823797.0000
# 6                               PHELPS  COMER         166767959.0000
# 7                         AETOS SYSTEMS  INC.         805721268.0000
# 8                              NAPHCARE  INC.           4677399.0000
# 9                              NAPHCARE  INC.           4677399.0000
#
#   recipient_country_code recipient_city_name  ...  \
# 0                    USA          HUNTSVILLE  ...
# 1                    USA          BIRMINGHAM  ...
# 2                    USA          HUNTSVILLE  ...
# 3                    USA             DECATUR  ...
# 4                    USA              MOBILE  ...
# 5                    USA          TUSCALOOSA  ...
# 6                    USA                TROY  ...
# 7                    USA          HUNTSVILLE  ...
# 8                    USA          BIRMINGHAM  ...
# 9                    USA          BIRMINGHAM  ...
#
#   primary_place_of_performance_state_code award_or_idv_flag      award_type  \
# 0                                      AL             AWARD  DELIVERY ORDER
# 1                                     NaN               IDV             NaN
# 2                                     NaN               IDV             NaN
# 3                                     NaN               IDV             NaN
# 4                                     NaN               IDV             NaN
# 5                                     NaN               IDV             NaN
# 6                                     NaN               IDV             NaN
# 7                                     NaN               IDV             NaN
# 8                                      CA             AWARD        BPA CALL
# 9                                      CA             AWARD        BPA CALL
#
#   type_of_contract_pricing_code  \
# 0                             J
# 1                             1
# 2                             J
# 3                             K
# 4                             J
# 5                             J
# 6                             K
# 7                             J
# 8                             J
# 9                             J
#
#                             type_of_contract_pricing  \
# 0                                   FIRM FIXED PRICE
# 1  ORDER DEPENDENT (IDV ALLOWS PRICING ARRANGEMEN...
# 2                                   FIRM FIXED PRICE
# 3         FIXED PRICE WITH ECONOMIC PRICE ADJUSTMENT
# 4                                   FIRM FIXED PRICE
# 5                                   FIRM FIXED PRICE
# 6         FIXED PRICE WITH ECONOMIC PRICE ADJUSTMENT
# 7                                   FIRM FIXED PRICE
# 8                                   FIRM FIXED PRICE
# 9                                   FIRM FIXED PRICE
#
#                  product_or_service_code_description  naics_code  \
# 0       SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL 541712.0000
# 1                       SUPPORT- PROFESSIONAL: OTHER 541611.0000
# 2  SUPPORT- PROFESSIONAL: MARKET RESEARCH/PUBLIC ... 541330.0000
# 3                            FIRE FIGHTING EQUIPMENT 315992.0000
# 4    IT AND TELECOM- OTHER IT AND TELECOMMUNICATIONS 541512.0000
# 5  MEMORIALS; CEMETERIAL AND MORTUARY EQUIPMENT A... 339999.0000
# 6  TRANSPORTATION/TRAVEL/RELOCATION- TRANSPORTATI... 484220.0000
# 7                       SUPPORT- PROFESSIONAL: OTHER 561210.0000
# 8                                     MEDICAL- OTHER 622110.0000
# 9                       MEDICAL- GENERAL HEALTH CARE 622110.0000
#
#                                    naics_description  \
# 0  RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...
# 1  ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...
# 2                               ENGINEERING SERVICES
# 3                     GLOVE AND MITTEN MANUFACTURING
# 4                   COMPUTER SYSTEMS DESIGN SERVICES
# 5              ALL OTHER MISCELLANEOUS MANUFACTURING
# 6  SPECIALIZED FREIGHT (EXCEPT USED GOODS) TRUCKI...
# 7                        FACILITIES SUPPORT SERVICES
# 8             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 9             GENERAL MEDICAL AND SURGICAL HOSPITALS
#
#   domestic_or_foreign_entity country_of_product_or_service_origin_code  \
# 0        U.S. OWNED BUSINESS                                       USA
# 1        U.S. OWNED BUSINESS                                       NaN
# 2        U.S. OWNED BUSINESS                                       NaN
# 3        U.S. OWNED BUSINESS                                       NaN
# 4        U.S. OWNED BUSINESS                                       NaN
# 5        U.S. OWNED BUSINESS                                       NaN
# 6        U.S. OWNED BUSINESS                                       NaN
# 7        U.S. OWNED BUSINESS                                       NaN
# 8        U.S. OWNED BUSINESS                                       USA
# 9        U.S. OWNED BUSINESS                                       USA
#
#              place_of_manufacture  \
# 0  NOT A MANUFACTURED END PRODUCT
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8  NOT A MANUFACTURED END PRODUCT
# 9  NOT A MANUFACTURED END PRODUCT
#
#                                      extent_competed  \
# 0                          FULL AND OPEN COMPETITION
# 1                          FULL AND OPEN COMPETITION
# 2                          FULL AND OPEN COMPETITION
# 3                          FULL AND OPEN COMPETITION
# 4                          FULL AND OPEN COMPETITION
# 5                                 COMPETED UNDER SAP
# 6  FULL AND OPEN COMPETITION AFTER EXCLUSION OF S...
# 7                      NOT AVAILABLE FOR COMPETITION
# 8                             NOT COMPETED UNDER SAP
# 9                             NOT COMPETED UNDER SAP
#
#                       solicitation_procedures veteran_owned_business  \
# 0  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY                      f
# 1  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY                      f
# 2                   NEGOTIATED PROPOSAL/QUOTE                      f
# 3                   NEGOTIATED PROPOSAL/QUOTE                      f
# 4                   NEGOTIATED PROPOSAL/QUOTE                      f
# 5                      SIMPLIFIED ACQUISITION                      f
# 6                   NEGOTIATED PROPOSAL/QUOTE                      f
# 7                             ONLY ONE SOURCE                      f
# 8                      SIMPLIFIED ACQUISITION                      f
# 9                      SIMPLIFIED ACQUISITION                      f
#
#   woman_owned_business minority_owned_business       organizational_type  \
# 0                    f                       t  CORPORATE NOT TAX EXEMPT
# 1                    f                       f                     OTHER
# 2                    t                       f  CORPORATE NOT TAX EXEMPT
# 3                    f                       f  CORPORATE NOT TAX EXEMPT
# 4                    f                       f  CORPORATE NOT TAX EXEMPT
# 5                    f                       f               PARTNERSHIP
# 6                    f                       f       SOLE PROPRIETORSHIP
# 7                    t                       t  CORPORATE NOT TAX EXEMPT
# 8                    f                       f                     OTHER
# 9                    f                       f                     OTHER
#
#   for_profit_organization nonprofit_organization awarding_agency_abbr
# 0                       t                      f                 NASA
# 1                       t                      f                  HHS
# 2                       t                      f                  GSA
# 3                       t                      f                  GSA
# 4                       t                      f                  GSA
# 5                       t                      f                   VA
# 6                       t                      f                 USDA
# 7                       t                      f                 NASA
# 8                       t                      f                  DOJ
# 9                       t                      f                  DOJ
#
# [10 rows x 44 columns]

# %% [markdown]
# Similar to the layout of data in Excel, a pandas DataFrame has row and column labels. The row labels of a pandas DataFrame are given in the `index` and the column labels in the `columns`. We can access these labels using the `index` and `columns` attributes.

# %%
data.index
# Out:
# RangeIndex(start=0, stop=106399, step=1)

# %%
data.columns
# Out:
# Index(['award_id_piid', 'parent_award_agency_name', 'parent_award_id',
#        'total_dollars_obligated', 'current_total_value_of_award',
#        'potential_total_value_of_award', 'action_date', 'awarding_agency_name',
#        'awarding_sub_agency_name', 'awarding_office_name',
#        'funding_agency_code', 'funding_agency_name', 'funding_sub_agency_name',
#        'funding_office_name', 'recipient_duns', 'recipient_name',
#        'recipient_parent_name', 'recipient_parent_duns',
#        'recipient_country_code', 'recipient_city_name', 'recipient_state_code',
#        'primary_place_of_performance_country_code',
#        'primary_place_of_performance_city_name',
#        'primary_place_of_performance_county_name',
#        'primary_place_of_performance_state_code', 'award_or_idv_flag',
#        'award_type', 'type_of_contract_pricing_code',
#        'type_of_contract_pricing', 'product_or_service_code_description',
#        'naics_code', 'naics_description', 'domestic_or_foreign_entity',
#        'country_of_product_or_service_origin_code', 'place_of_manufacture',
#        'extent_competed', 'solicitation_procedures', 'veteran_owned_business',
#        'woman_owned_business', 'minority_owned_business',
#        'organizational_type', 'for_profit_organization',
#        'nonprofit_organization', 'awarding_agency_abbr'],
#       dtype='object')

# %% [markdown]
# Notice that the type of the object returned by both of these attributes is some type of an Index.

# %%
type(data.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
type(data.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# Pandas index types have a `tolist` method that allows us to convert the index to a python list.

# %%
data.columns.tolist()
# Out:
# ['award_id_piid',
#  'parent_award_agency_name',
#  'parent_award_id',
#  'total_dollars_obligated',
#  'current_total_value_of_award',
#  'potential_total_value_of_award',
#  'action_date',
#  'awarding_agency_name',
#  'awarding_sub_agency_name',
#  'awarding_office_name',
#  'funding_agency_code',
#  'funding_agency_name',
#  'funding_sub_agency_name',
#  'funding_office_name',
#  'recipient_duns',
#  'recipient_name',
#  'recipient_parent_name',
#  'recipient_parent_duns',
#  'recipient_country_code',
#  'recipient_city_name',
#  'recipient_state_code',
#  'primary_place_of_performance_country_code',
#  'primary_place_of_performance_city_name',
#  'primary_place_of_performance_county_name',
#  'primary_place_of_performance_state_code',
#  'award_or_idv_flag',
#  'award_type',
#  'type_of_contract_pricing_code',
#  'type_of_contract_pricing',
#  'product_or_service_code_description',
#  'naics_code',
#  'naics_description',
#  'domestic_or_foreign_entity',
#  'country_of_product_or_service_origin_code',
#  'place_of_manufacture',
#  'extent_competed',
#  'solicitation_procedures',
#  'veteran_owned_business',
#  'woman_owned_business',
#  'minority_owned_business',
#  'organizational_type',
#  'for_profit_organization',
#  'nonprofit_organization',
#  'awarding_agency_abbr']

# %% [markdown]
# There is also a `describe` method available for DataFrames. By default, it summarizes numerical columns only.

# %%
data.describe()
# Out:
#        total_dollars_obligated  current_total_value_of_award  \
# count              106399.0000                   103137.0000
# mean             12258995.1439                 14472980.6439
# std             220363249.3007                257653114.7485
# min             -16072760.9200                -16072760.9200
# 25%                   201.9850                      219.9700
# 50%                   420.7900                      438.5900
# 75%                  2942.3000                     3434.0000
# max            6999977801.5300              10620099286.6900
#
#        potential_total_value_of_award  funding_agency_code  recipient_duns  \
# count                     106399.0000          106399.0000     106399.0000
# mean                   516261349.5103              91.9665  273158211.5619
# std                  19782465090.8888              40.2055  306873801.3742
# min                    -16072760.9100               5.0000    1011675.0000
# 25%                          224.2650              97.0000   99841090.0000
# 50%                          456.6700              97.0000  130368145.0000
# 75%                         5941.5650              97.0000  185169620.0000
# max                1015692392330.0000            3302.0000  969851661.0000
#
#        recipient_parent_duns  naics_code
# count            106398.0000 106384.0000
# mean          255136336.1882 363626.2005
# std           284262007.3588  98491.7128
# min             1011675.0000 111199.0000
# 25%           120909460.0000 311991.0000
# 50%           130368145.0000 324110.0000
# 75%           212078364.0000 339999.0000
# max           985594574.0000 928110.0000

# %% [markdown]
# We will be using the `total_dollars_obligated` data as a proxy for expenditures. Notice in the previous summary that this data includes negative values, which may mean that some entity owes the government money. Suppose we want to exclude any non-positive values. To do this we first grab the column.

# %%
data['total_dollars_obligated']
# Out:
# 0         109775.1200
# 1              0.0000
# 2              0.0000
# 3              0.0000
# 4              0.0000
#              ...
# 106394   1538952.0000
# 106395    203428.0000
# 106396    111794.4600
# 106397     73495.1300
# 106398    556987.4800
# Name: total_dollars_obligated, Length: 106399, dtype: float64

# %% [markdown]
# Just as an aside, note that the column is a pandas series.

# %%
type(data['total_dollars_obligated'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Pandas is built *on top* of another popular library named `numpy`. The primary objective of numpy is to allow for fast numerical computations on matrices or vectors (it is actually a python wrapper for many fast implementations in C). The presence of numpy can be observed if we try to determine which rows include values less than or equal to zero.

# %%
data['total_dollars_obligated'] <= 0
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 106394    False
# 106395    False
# 106396    False
# 106397    False
# 106398    False
# Name: total_dollars_obligated, Length: 106399, dtype: bool

# %% [markdown]
# Note that the comparison provides a pandas series with `True` or `False` for each of the index (row) values.

# %%
type(data['total_dollars_obligated'] <= 0)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Since the result is a series, we can save it as variable.

# %%
mask = data['total_dollars_obligated'] <= 0
mask
# Out:
# 0         False
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 106394    False
# 106395    False
# 106396    False
# 106397    False
# 106398    False
# Name: total_dollars_obligated, Length: 106399, dtype: bool

# %% [markdown]
# With the series saved, we can use it to quickly subset and overwrite the data.

# %%
data = data[~mask]
data.head()
# Out:
#         award_id_piid                   parent_award_agency_name  \
# 0       80NSSC17F0945                FEDERAL ACQUISITION SERVICE
# 7          NNM16AA27C                                        NaN
# 8   15B61919FUB110010  FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 9   15B61919FUB210001  FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 10      36C24718C0044                                        NaN
#
#      parent_award_id  total_dollars_obligated  current_total_value_of_award  \
# 0         GS00F0004X              109775.1200                   109775.1200
# 7                NaN             3877805.0000                           nan
# 8   DJBP0619BPA14008                2400.0000                     2400.0000
# 9   DJBP0619BPA14008               50000.0000                    50000.0000
# 10               NaN               28800.0000                    28800.0000
#
#     potential_total_value_of_award action_date  \
# 0                      109775.1200  2019-04-24
# 7                     5274465.0000  2018-10-01
# 8                        2400.0000  2018-10-02
# 9                       50000.0000  2018-10-02
# 10                      72000.0000  2018-10-01
#
#                                  awarding_agency_name  \
# 0   NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 7   NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 8                         DEPARTMENT OF JUSTICE (DOJ)
# 9                         DEPARTMENT OF JUSTICE (DOJ)
# 10                DEPARTMENT OF VETERANS AFFAIRS (VA)
#
#                          awarding_sub_agency_name  \
# 0   NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 7   NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 8       FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 9       FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 10                VETERANS AFFAIRS, DEPARTMENT OF
#
#                  awarding_office_name  funding_agency_code  \
# 0         NASA SHARED SERVICES CENTER                   80
# 7   NASA MARSHALL SPACE FLIGHT CENTER                   80
# 8   DEPT OF JUSTICE BUREAU OF PRISONS                   15
# 9   DEPT OF JUSTICE BUREAU OF PRISONS                   15
# 10  247-NETWORK CONTRACT OFC 7(00247)                   36
#
#                                   funding_agency_name  \
# 0   NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 7   NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 8                         DEPARTMENT OF JUSTICE (DOJ)
# 9                         DEPARTMENT OF JUSTICE (DOJ)
# 10                DEPARTMENT OF VETERANS AFFAIRS (VA)
#
#                           funding_sub_agency_name  \
# 0   NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 7   NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 8       FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 9       FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 10                VETERANS AFFAIRS, DEPARTMENT OF
#
#                     funding_office_name  recipient_duns  \
# 0           NASA SHARED SERVICES CENTER       618735948
# 7     NASA MARSHALL SPACE FLIGHT CENTER       805721268
# 8     DEPT OF JUSTICE BUREAU OF PRISONS         4677399
# 9     DEPT OF JUSTICE BUREAU OF PRISONS         4677399
# 10  619-CENTERAL ALABAM (00619)(36C619)       140381448
#
#                           recipient_name recipient_parent_name  \
# 0                       TEC-MASTERS INC.      TEC-MASTERS INC.
# 7                    AETOS SYSTEMS, INC.   AETOS SYSTEMS  INC.
# 8                         NAPHCARE, INC.        NAPHCARE  INC.
# 9                         NAPHCARE, INC.        NAPHCARE  INC.
# 10  ALABAMA STATE LAW ENFORCEMENT AGENCY      STATE OF ALABAMA
#
#     recipient_parent_duns recipient_country_code recipient_city_name  ...  \
# 0          618735948.0000                    USA          HUNTSVILLE  ...
# 7          805721268.0000                    USA          HUNTSVILLE  ...
# 8            4677399.0000                    USA          BIRMINGHAM  ...
# 9            4677399.0000                    USA          BIRMINGHAM  ...
# 10           4027553.0000                    USA          MONTGOMERY  ...
#
#    primary_place_of_performance_state_code award_or_idv_flag  \
# 0                                       AL             AWARD
# 7                                      NaN               IDV
# 8                                       CA             AWARD
# 9                                       CA             AWARD
# 10                                      AL             AWARD
#
#              award_type type_of_contract_pricing_code  \
# 0        DELIVERY ORDER                             J
# 7                   NaN                             J
# 8              BPA CALL                             J
# 9              BPA CALL                             J
# 10  DEFINITIVE CONTRACT                             J
#
#    type_of_contract_pricing  \
# 0          FIRM FIXED PRICE
# 7          FIRM FIXED PRICE
# 8          FIRM FIXED PRICE
# 9          FIRM FIXED PRICE
# 10         FIRM FIXED PRICE
#
#                   product_or_service_code_description  naics_code  \
# 0        SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL 541712.0000
# 7                        SUPPORT- PROFESSIONAL: OTHER 561210.0000
# 8                                      MEDICAL- OTHER 622110.0000
# 9                        MEDICAL- GENERAL HEALTH CARE 622110.0000
# 10  SUPPORT- ADMINISTRATIVE: BACKGROUND INVESTIGATION 561611.0000
#
#                                     naics_description  \
# 0   RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...
# 7                         FACILITIES SUPPORT SERVICES
# 8              GENERAL MEDICAL AND SURGICAL HOSPITALS
# 9              GENERAL MEDICAL AND SURGICAL HOSPITALS
# 10                             INVESTIGATION SERVICES
#
#              domestic_or_foreign_entity  \
# 0                   U.S. OWNED BUSINESS
# 7                   U.S. OWNED BUSINESS
# 8                   U.S. OWNED BUSINESS
# 9                   U.S. OWNED BUSINESS
# 10  OTHER U.S. ENTITY (E.G. GOVERNMENT)
#
#    country_of_product_or_service_origin_code            place_of_manufacture  \
# 0                                        USA  NOT A MANUFACTURED END PRODUCT
# 7                                        NaN                             NaN
# 8                                        USA  NOT A MANUFACTURED END PRODUCT
# 9                                        USA  NOT A MANUFACTURED END PRODUCT
# 10                                       USA  NOT A MANUFACTURED END PRODUCT
#
#                   extent_competed                     solicitation_procedures  \
# 0       FULL AND OPEN COMPETITION  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# 7   NOT AVAILABLE FOR COMPETITION                             ONLY ONE SOURCE
# 8          NOT COMPETED UNDER SAP                      SIMPLIFIED ACQUISITION
# 9          NOT COMPETED UNDER SAP                      SIMPLIFIED ACQUISITION
# 10         NOT COMPETED UNDER SAP                      SIMPLIFIED ACQUISITION
#
#    veteran_owned_business woman_owned_business minority_owned_business  \
# 0                       f                    f                       t
# 7                       f                    t                       t
# 8                       f                    f                       f
# 9                       f                    f                       f
# 10                      f                    f                       f
#
#          organizational_type for_profit_organization nonprofit_organization  \
# 0   CORPORATE NOT TAX EXEMPT                       t                      f
# 7   CORPORATE NOT TAX EXEMPT                       t                      f
# 8                      OTHER                       t                      f
# 9                      OTHER                       t                      f
# 10      US GOVERNMENT ENTITY                       f                      f
#
#    awarding_agency_abbr
# 0                  NASA
# 7                  NASA
# 8                   DOJ
# 9                   DOJ
# 10                   VA
#
# [5 rows x 44 columns]

# %% [markdown]
# We can use the `reset_index` method to reset the index.

# %%
data = data.reset_index(drop = True)
data.head()
# Out:
#        award_id_piid                   parent_award_agency_name  \
# 0      80NSSC17F0945                FEDERAL ACQUISITION SERVICE
# 1         NNM16AA27C                                        NaN
# 2  15B61919FUB110010  FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 3  15B61919FUB210001  FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 4      36C24718C0044                                        NaN
#
#     parent_award_id  total_dollars_obligated  current_total_value_of_award  \
# 0        GS00F0004X              109775.1200                   109775.1200
# 1               NaN             3877805.0000                           nan
# 2  DJBP0619BPA14008                2400.0000                     2400.0000
# 3  DJBP0619BPA14008               50000.0000                    50000.0000
# 4               NaN               28800.0000                    28800.0000
#
#    potential_total_value_of_award action_date  \
# 0                     109775.1200  2019-04-24
# 1                    5274465.0000  2018-10-01
# 2                       2400.0000  2018-10-02
# 3                      50000.0000  2018-10-02
# 4                      72000.0000  2018-10-01
#
#                                 awarding_agency_name  \
# 0  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 1  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 2                        DEPARTMENT OF JUSTICE (DOJ)
# 3                        DEPARTMENT OF JUSTICE (DOJ)
# 4                DEPARTMENT OF VETERANS AFFAIRS (VA)
#
#                         awarding_sub_agency_name  \
# 0  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 1  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 2      FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 3      FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 4                VETERANS AFFAIRS, DEPARTMENT OF
#
#                 awarding_office_name  funding_agency_code  \
# 0        NASA SHARED SERVICES CENTER                   80
# 1  NASA MARSHALL SPACE FLIGHT CENTER                   80
# 2  DEPT OF JUSTICE BUREAU OF PRISONS                   15
# 3  DEPT OF JUSTICE BUREAU OF PRISONS                   15
# 4  247-NETWORK CONTRACT OFC 7(00247)                   36
#
#                                  funding_agency_name  \
# 0  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 1  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION ...
# 2                        DEPARTMENT OF JUSTICE (DOJ)
# 3                        DEPARTMENT OF JUSTICE (DOJ)
# 4                DEPARTMENT OF VETERANS AFFAIRS (VA)
#
#                          funding_sub_agency_name  \
# 0  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 1  NATIONAL AERONAUTICS AND SPACE ADMINISTRATION
# 2      FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 3      FEDERAL PRISON SYSTEM / BUREAU OF PRISONS
# 4                VETERANS AFFAIRS, DEPARTMENT OF
#
#                    funding_office_name  recipient_duns  \
# 0          NASA SHARED SERVICES CENTER       618735948
# 1    NASA MARSHALL SPACE FLIGHT CENTER       805721268
# 2    DEPT OF JUSTICE BUREAU OF PRISONS         4677399
# 3    DEPT OF JUSTICE BUREAU OF PRISONS         4677399
# 4  619-CENTERAL ALABAM (00619)(36C619)       140381448
#
#                          recipient_name recipient_parent_name  \
# 0                      TEC-MASTERS INC.      TEC-MASTERS INC.
# 1                   AETOS SYSTEMS, INC.   AETOS SYSTEMS  INC.
# 2                        NAPHCARE, INC.        NAPHCARE  INC.
# 3                        NAPHCARE, INC.        NAPHCARE  INC.
# 4  ALABAMA STATE LAW ENFORCEMENT AGENCY      STATE OF ALABAMA
#
#    recipient_parent_duns recipient_country_code recipient_city_name  ...  \
# 0         618735948.0000                    USA          HUNTSVILLE  ...
# 1         805721268.0000                    USA          HUNTSVILLE  ...
# 2           4677399.0000                    USA          BIRMINGHAM  ...
# 3           4677399.0000                    USA          BIRMINGHAM  ...
# 4           4027553.0000                    USA          MONTGOMERY  ...
#
#   primary_place_of_performance_state_code award_or_idv_flag  \
# 0                                      AL             AWARD
# 1                                     NaN               IDV
# 2                                      CA             AWARD
# 3                                      CA             AWARD
# 4                                      AL             AWARD
#
#             award_type type_of_contract_pricing_code type_of_contract_pricing  \
# 0       DELIVERY ORDER                             J         FIRM FIXED PRICE
# 1                  NaN                             J         FIRM FIXED PRICE
# 2             BPA CALL                             J         FIRM FIXED PRICE
# 3             BPA CALL                             J         FIRM FIXED PRICE
# 4  DEFINITIVE CONTRACT                             J         FIRM FIXED PRICE
#
#                  product_or_service_code_description  naics_code  \
# 0       SUPPORT- PROFESSIONAL: ENGINEERING/TECHNICAL 541712.0000
# 1                       SUPPORT- PROFESSIONAL: OTHER 561210.0000
# 2                                     MEDICAL- OTHER 622110.0000
# 3                       MEDICAL- GENERAL HEALTH CARE 622110.0000
# 4  SUPPORT- ADMINISTRATIVE: BACKGROUND INVESTIGATION 561611.0000
#
#                                    naics_description  \
# 0  RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...
# 1                        FACILITIES SUPPORT SERVICES
# 2             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 3             GENERAL MEDICAL AND SURGICAL HOSPITALS
# 4                             INVESTIGATION SERVICES
#
#             domestic_or_foreign_entity  \
# 0                  U.S. OWNED BUSINESS
# 1                  U.S. OWNED BUSINESS
# 2                  U.S. OWNED BUSINESS
# 3                  U.S. OWNED BUSINESS
# 4  OTHER U.S. ENTITY (E.G. GOVERNMENT)
#
#   country_of_product_or_service_origin_code            place_of_manufacture  \
# 0                                       USA  NOT A MANUFACTURED END PRODUCT
# 1                                       NaN                             NaN
# 2                                       USA  NOT A MANUFACTURED END PRODUCT
# 3                                       USA  NOT A MANUFACTURED END PRODUCT
# 4                                       USA  NOT A MANUFACTURED END PRODUCT
#
#                  extent_competed                     solicitation_procedures  \
# 0      FULL AND OPEN COMPETITION  SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY
# 1  NOT AVAILABLE FOR COMPETITION                             ONLY ONE SOURCE
# 2         NOT COMPETED UNDER SAP                      SIMPLIFIED ACQUISITION
# 3         NOT COMPETED UNDER SAP                      SIMPLIFIED ACQUISITION
# 4         NOT COMPETED UNDER SAP                      SIMPLIFIED ACQUISITION
#
#   veteran_owned_business woman_owned_business minority_owned_business  \
# 0                      f                    f                       t
# 1                      f                    t                       t
# 2                      f                    f                       f
# 3                      f                    f                       f
# 4                      f                    f                       f
#
#         organizational_type for_profit_organization nonprofit_organization  \
# 0  CORPORATE NOT TAX EXEMPT                       t                      f
# 1  CORPORATE NOT TAX EXEMPT                       t                      f
# 2                     OTHER                       t                      f
# 3                     OTHER                       t                      f
# 4      US GOVERNMENT ENTITY                       f                      f
#
#   awarding_agency_abbr
# 0                 NASA
# 1                 NASA
# 2                  DOJ
# 3                  DOJ
# 4                   VA
#
# [5 rows x 44 columns]

# %% [markdown]
# ## Which products/services are being purchased?
#
# We will now proceed to investigate the first question: Which products/services are being purchased?
#
# Let's begin by reminding ourselves of the available columns.

# %%
data.columns
# Out:
# Index(['award_id_piid', 'parent_award_agency_name', 'parent_award_id',
#        'total_dollars_obligated', 'current_total_value_of_award',
#        'potential_total_value_of_award', 'action_date', 'awarding_agency_name',
#        'awarding_sub_agency_name', 'awarding_office_name',
#        'funding_agency_code', 'funding_agency_name', 'funding_sub_agency_name',
#        'funding_office_name', 'recipient_duns', 'recipient_name',
#        'recipient_parent_name', 'recipient_parent_duns',
#        'recipient_country_code', 'recipient_city_name', 'recipient_state_code',
#        'primary_place_of_performance_country_code',
#        'primary_place_of_performance_city_name',
#        'primary_place_of_performance_county_name',
#        'primary_place_of_performance_state_code', 'award_or_idv_flag',
#        'award_type', 'type_of_contract_pricing_code',
#        'type_of_contract_pricing', 'product_or_service_code_description',
#        'naics_code', 'naics_description', 'domestic_or_foreign_entity',
#        'country_of_product_or_service_origin_code', 'place_of_manufacture',
#        'extent_competed', 'solicitation_procedures', 'veteran_owned_business',
#        'woman_owned_business', 'minority_owned_business',
#        'organizational_type', 'for_profit_organization',
#        'nonprofit_organization', 'awarding_agency_abbr'],
#       dtype='object')

# %% [markdown]
# The North American Industry Classification System (NAICS) is the standard used by Federal agencies in classifying business establishments for the purpose of collecting, analyzing, and publishing data related to the U.S. business economy. We will use the NAICS codes provided as a proxy for the product/service type.
#
# In order to determine the products/services most frequently bought, we will use the groupby functionality of pandas (see https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html and https://realpython.com/pandas-groupby/#how-pandas-groupby-works for a more complete introduction). The following code block shows how we can use this functionality to group the data by `naics_code` and `naics_description`, counting the number of unique (`nunique`) awards for each group.

# %%
grouped_data = data.groupby(['naics_code', 'naics_description']).agg({'award_id_piid':'nunique'})
grouped_data
# Out:
#                                                                 award_id_piid
# naics_code  naics_description
# 111199.0000 ALL OTHER GRAIN FARMING                                         1
# 111421.0000 NURSERY AND TREE PRODUCTION                                     1
# 111998.0000 ALL OTHER MISCELLANEOUS CROP FARMING                            4
# 112990.0000 ALL OTHER ANIMAL PRODUCTION                                     4
# 113110.0000 TIMBER TRACT OPERATIONS                                         2
# ...                                                                       ...
# 923110.0000 ADMINISTRATION OF EDUCATION PROGRAMS                            5
# 923120.0000 ADMINISTRATION OF PUBLIC HEALTH PROGRAMS                       19
# 924110.0000 ADMINISTRATION OF AIR AND WATER RESOURCE AND SO...              1
# 924120.0000 ADMINISTRATION OF CONSERVATION PROGRAMS                         1
# 927110.0000 SPACE RESEARCH AND TECHNOLOGY                                   1
#
# [536 rows x 1 columns]

# %% [markdown]
# Notice that the object returned is a DataFrame.

# %%
type(grouped_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# In this case, we have a multidimensional index.

# %%
grouped_data.index
# Out:
# MultiIndex([(111199.0, ...),
#             (111421.0, ...),
#             (111998.0, ...),
#             (112990.0, ...),
#             (113110.0, ...),
#             (114119.0, ...),
#             (115112.0, ...),
#             (115310.0, ...),
#             (211111.0, ...),
#             (211130.0, ...),
#             ...
#             (922110.0, ...),
#             (922120.0, ...),
#             (922140.0, ...),
#             (922160.0, ...),
#             (922190.0, ...),
#             (923110.0, ...),
#             (923120.0, ...),
#             (924110.0, ...),
#             (924120.0, ...),
#             (927110.0, ...)],
#            names=['naics_code', 'naics_description'], length=536)

# %% [markdown]
# The pandas groupby functionality is rather flexible. However, I find it easiest to utilize an approach for grouping that uses a dictionary for defining the desired aggregations and passes the dictionary to the `agg` method. This method is demonstratedin the following code block.

# %%
agg_dict = {'award_id_piid':'nunique',
            'total_dollars_obligated': 'sum'}

agg_columns = ['naics_code', 'naics_description']

grouped_data = data.groupby(agg_columns).agg(agg_dict)

grouped_data
# Out:
#                                                                 award_id_piid  \
# naics_code  naics_description
# 111199.0000 ALL OTHER GRAIN FARMING                                         1
# 111421.0000 NURSERY AND TREE PRODUCTION                                     1
# 111998.0000 ALL OTHER MISCELLANEOUS CROP FARMING                            4
# 112990.0000 ALL OTHER ANIMAL PRODUCTION                                     4
# 113110.0000 TIMBER TRACT OPERATIONS                                         2
# ...                                                                       ...
# 923110.0000 ADMINISTRATION OF EDUCATION PROGRAMS                            5
# 923120.0000 ADMINISTRATION OF PUBLIC HEALTH PROGRAMS                       19
# 924110.0000 ADMINISTRATION OF AIR AND WATER RESOURCE AND SO...              1
# 924120.0000 ADMINISTRATION OF CONSERVATION PROGRAMS                         1
# 927110.0000 SPACE RESEARCH AND TECHNOLOGY                                   1
#
#                                                                 total_dollars_obligated
# naics_code  naics_description
# 111199.0000 ALL OTHER GRAIN FARMING                                         178440.0000
# 111421.0000 NURSERY AND TREE PRODUCTION                                       5000.0000
# 111998.0000 ALL OTHER MISCELLANEOUS CROP FARMING                            247224.1000
# 112990.0000 ALL OTHER ANIMAL PRODUCTION                                     294800.0000
# 113110.0000 TIMBER TRACT OPERATIONS                                          36732.9000
# ...                                                                                 ...
# 923110.0000 ADMINISTRATION OF EDUCATION PROGRAMS                           3212568.9100
# 923120.0000 ADMINISTRATION OF PUBLIC HEALTH PROGRAMS                      11178546.3500
# 924110.0000 ADMINISTRATION OF AIR AND WATER RESOURCE AND SO...             1775132.0000
# 924120.0000 ADMINISTRATION OF CONSERVATION PROGRAMS                          13667.1100
# 927110.0000 SPACE RESEARCH AND TECHNOLOGY                                 75514865.5700
#
# [536 rows x 2 columns]

# %% [markdown]
# Due to the underlying dependence on numpy, calculations on the columns are easy.

# %%
grouped_data['dollar_obligated_proportion'] = (grouped_data['total_dollars_obligated']
                                               /grouped_data['total_dollars_obligated'].sum())

grouped_data['awards_proportion'] = (grouped_data['award_id_piid']/
                                     grouped_data['award_id_piid'].sum())

grouped_data
# Out:
#                                                                 award_id_piid  \
# naics_code  naics_description
# 111199.0000 ALL OTHER GRAIN FARMING                                         1
# 111421.0000 NURSERY AND TREE PRODUCTION                                     1
# 111998.0000 ALL OTHER MISCELLANEOUS CROP FARMING                            4
# 112990.0000 ALL OTHER ANIMAL PRODUCTION                                     4
# 113110.0000 TIMBER TRACT OPERATIONS                                         2
# ...                                                                       ...
# 923110.0000 ADMINISTRATION OF EDUCATION PROGRAMS                            5
# 923120.0000 ADMINISTRATION OF PUBLIC HEALTH PROGRAMS                       19
# 924110.0000 ADMINISTRATION OF AIR AND WATER RESOURCE AND SO...              1
# 924120.0000 ADMINISTRATION OF CONSERVATION PROGRAMS                         1
# 927110.0000 SPACE RESEARCH AND TECHNOLOGY                                   1
#
#                                                                 total_dollars_obligated  \
# naics_code  naics_description
# 111199.0000 ALL OTHER GRAIN FARMING                                         178440.0000
# 111421.0000 NURSERY AND TREE PRODUCTION                                       5000.0000
# 111998.0000 ALL OTHER MISCELLANEOUS CROP FARMING                            247224.1000
# 112990.0000 ALL OTHER ANIMAL PRODUCTION                                     294800.0000
# 113110.0000 TIMBER TRACT OPERATIONS                                          36732.9000
# ...                                                                                 ...
# 923110.0000 ADMINISTRATION OF EDUCATION PROGRAMS                           3212568.9100
# 923120.0000 ADMINISTRATION OF PUBLIC HEALTH PROGRAMS                      11178546.3500
# 924110.0000 ADMINISTRATION OF AIR AND WATER RESOURCE AND SO...             1775132.0000
# 924120.0000 ADMINISTRATION OF CONSERVATION PROGRAMS                          13667.1100
# 927110.0000 SPACE RESEARCH AND TECHNOLOGY                                 75514865.5700
#
#                                                                 dollar_obligated_proportion  \
# naics_code  naics_description
# 111199.0000 ALL OTHER GRAIN FARMING                                                  0.0000
# 111421.0000 NURSERY AND TREE PRODUCTION                                              0.0000
# 111998.0000 ALL OTHER MISCELLANEOUS CROP FARMING                                     0.0000
# 112990.0000 ALL OTHER ANIMAL PRODUCTION                                              0.0000
# 113110.0000 TIMBER TRACT OPERATIONS                                                  0.0000
# ...                                                                                     ...
# 923110.0000 ADMINISTRATION OF EDUCATION PROGRAMS                                     0.0000
# 923120.0000 ADMINISTRATION OF PUBLIC HEALTH PROGRAMS                                 0.0000
# 924110.0000 ADMINISTRATION OF AIR AND WATER RESOURCE AND SO...                       0.0000
# 924120.0000 ADMINISTRATION OF CONSERVATION PROGRAMS                                  0.0000
# 927110.0000 SPACE RESEARCH AND TECHNOLOGY                                            0.0001
#
#                                                                 awards_proportion
# naics_code  naics_description
# 111199.0000 ALL OTHER GRAIN FARMING                                        0.0000
# 111421.0000 NURSERY AND TREE PRODUCTION                                    0.0000
# 111998.0000 ALL OTHER MISCELLANEOUS CROP FARMING                           0.0000
# 112990.0000 ALL OTHER ANIMAL PRODUCTION                                    0.0000
# 113110.0000 TIMBER TRACT OPERATIONS                                        0.0000
# ...                                                                           ...
# 923110.0000 ADMINISTRATION OF EDUCATION PROGRAMS                           0.0001
# 923120.0000 ADMINISTRATION OF PUBLIC HEALTH PROGRAMS                       0.0002
# 924110.0000 ADMINISTRATION OF AIR AND WATER RESOURCE AND SO...             0.0000
# 924120.0000 ADMINISTRATION OF CONSERVATION PROGRAMS                        0.0000
# 927110.0000 SPACE RESEARCH AND TECHNOLOGY                                  0.0000
#
# [536 rows x 4 columns]

# %% [markdown]
# The `nlargest` method allows us to quickly identify the subset of data associated with top values in one or more columns.

# %%
grouped_data.nlargest(10, columns = ['dollar_obligated_proportion'])
# Out:
#                                                                 award_id_piid  \
# naics_code  naics_description
# 541712.0000 RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGIN...            434
# 336611.0000 SHIP BUILDING AND REPAIRING                                   109
# 336414.0000 GUIDED MISSILE AND SPACE VEHICLE MANUFACTURING                  9
# 236220.0000 COMMERCIAL AND INSTITUTIONAL BUILDING CONSTRUCTION            536
# 541330.0000 ENGINEERING SERVICES                                          772
# 488190.0000 OTHER SUPPORT ACTIVITIES FOR AIR TRANSPORTATION                62
# 336419.0000 OTHER GUIDED MISSILE AND SPACE VEHICLE PARTS AN...             88
# 541714.0000 RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY (EXCE...             18
# 561210.0000 FACILITIES SUPPORT SERVICES                                   330
# 541511.0000 CUSTOM COMPUTER PROGRAMMING SERVICES                           88
#
#                                                                 total_dollars_obligated  \
# naics_code  naics_description
# 541712.0000 RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGIN...        475253219585.7905
# 336611.0000 SHIP BUILDING AND REPAIRING                               351942829101.2999
# 336414.0000 GUIDED MISSILE AND SPACE VEHICLE MANUFACTURING            225038179928.6901
# 236220.0000 COMMERCIAL AND INSTITUTIONAL BUILDING CONSTRUCTION         66659729707.8000
# 541330.0000 ENGINEERING SERVICES                                       37964420922.2800
# 488190.0000 OTHER SUPPORT ACTIVITIES FOR AIR TRANSPORTATION            24331359420.3500
# 336419.0000 OTHER GUIDED MISSILE AND SPACE VEHICLE PARTS AN...         24114006743.6500
# 541714.0000 RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY (EXCE...         19667259342.1700
# 561210.0000 FACILITIES SUPPORT SERVICES                                10955344569.1200
# 541511.0000 CUSTOM COMPUTER PROGRAMMING SERVICES                        9081177407.8900
#
#                                                                 dollar_obligated_proportion  \
# naics_code  naics_description
# 541712.0000 RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGIN...                       0.3644
# 336611.0000 SHIP BUILDING AND REPAIRING                                              0.2698
# 336414.0000 GUIDED MISSILE AND SPACE VEHICLE MANUFACTURING                           0.1725
# 236220.0000 COMMERCIAL AND INSTITUTIONAL BUILDING CONSTRUCTION                       0.0511
# 541330.0000 ENGINEERING SERVICES                                                     0.0291
# 488190.0000 OTHER SUPPORT ACTIVITIES FOR AIR TRANSPORTATION                          0.0187
# 336419.0000 OTHER GUIDED MISSILE AND SPACE VEHICLE PARTS AN...                       0.0185
# 541714.0000 RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY (EXCE...                       0.0151
# 561210.0000 FACILITIES SUPPORT SERVICES                                              0.0084
# 541511.0000 CUSTOM COMPUTER PROGRAMMING SERVICES                                     0.0070
#
#                                                                 awards_proportion
# naics_code  naics_description
# 541712.0000 RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGIN...             0.0048
# 336611.0000 SHIP BUILDING AND REPAIRING                                    0.0012
# 336414.0000 GUIDED MISSILE AND SPACE VEHICLE MANUFACTURING                 0.0001
# 236220.0000 COMMERCIAL AND INSTITUTIONAL BUILDING CONSTRUCTION             0.0059
# 541330.0000 ENGINEERING SERVICES                                           0.0085
# 488190.0000 OTHER SUPPORT ACTIVITIES FOR AIR TRANSPORTATION                0.0007
# 336419.0000 OTHER GUIDED MISSILE AND SPACE VEHICLE PARTS AN...             0.0010
# 541714.0000 RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY (EXCE...             0.0002
# 561210.0000 FACILITIES SUPPORT SERVICES                                    0.0036
# 541511.0000 CUSTOM COMPUTER PROGRAMMING SERVICES                           0.0010

# %% [markdown]
# The following code block shows how we can *chain* methods to save the top 10 NAICS values to a list. However, since we had a multidimensional index, our list is a list of tuples.

# %%
top_naics_codes = grouped_data.nlargest(10, columns = ['dollar_obligated_proportion']).index.tolist()
top_naics_codes
# Out:
# [(541712.0,
#   'RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGINEERING, AND LIFE SCIENCES (EXCEPT BIOTECHNOLOGY)'),
#  (336611.0, 'SHIP BUILDING AND REPAIRING'),
#  (336414.0, 'GUIDED MISSILE AND SPACE VEHICLE MANUFACTURING'),
#  (236220.0, 'COMMERCIAL AND INSTITUTIONAL BUILDING CONSTRUCTION'),
#  (541330.0, 'ENGINEERING SERVICES'),
#  (488190.0, 'OTHER SUPPORT ACTIVITIES FOR AIR TRANSPORTATION'),
#  (336419.0,
#   'OTHER GUIDED MISSILE AND SPACE VEHICLE PARTS AND AUXILIARY EQUIPMENT MANUFACTURING'),
#  (541714.0,
#   'RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY (EXCEPT NANOBIOTECHNOLOGY)'),
#  (561210.0, 'FACILITIES SUPPORT SERVICES'),
#  (541511.0, 'CUSTOM COMPUTER PROGRAMMING SERVICES')]

# %% [markdown]
# We will answer the remaining questions with respect to the top NAICS code. However, instead of hard-coding the NAICS code, we will just index the first value in the `top_naics_codes` list.

# %%
index_val = 0

top_naics_codes[index_val]
# Out:
# (541712.0,
#  'RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGINEERING, AND LIFE SCIENCES (EXCEPT BIOTECHNOLOGY)')

# %% [markdown]
# Note that this returns a `tuple`.

# %%
type(top_naics_codes[index_val])
# Out:
# tuple

# %% [markdown]
# We can get the NAICS code by accessing the first element of the tuple.

# %%
top_naics_codes[index_val][0]
# Out:
# 541712.0

# %% [markdown]
# We can get the NAICS description by accessing the second element of the tuple.

# %%
top_naics_codes[index_val][1]
# Out:
# 'RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGINEERING, AND LIFE SCIENCES (EXCEPT BIOTECHNOLOGY)'

# %% [markdown]
# The following code block saves these values as variables.

# %%
# Get NAICS code and description
naics_code = top_naics_codes[index_val][0]
naics_description = top_naics_codes[index_val][1]

# %% [markdown]
# The following code block saves the data associated with the current NAICS code as a variable named `naics_data`.

# %%
# Create a mask to subset the data
mask = data['naics_code'] == naics_code

# Get the data subset
naics_data = data[mask]

# %% [markdown]
# # Who is purchasing these products

# %% [markdown]
# The following code block determines the agencies with transactions associated with the target NAICS number and the total amount of money obligated.

# %%
# Group the data
agg_dict = {'award_id_piid':'nunique',
            'total_dollars_obligated': 'sum'}

agg_columns = ['awarding_agency_abbr', 'awarding_agency_name']


grouped_data = naics_data.groupby(agg_columns).agg(agg_dict)

# Calculate the proportions
grouped_data['dollar_obligated_proportion'] = (grouped_data['total_dollars_obligated']
                                               /grouped_data['total_dollars_obligated'].sum())

grouped_data['awards_proportion'] = (grouped_data['award_id_piid']
                                     /grouped_data['award_id_piid'].sum())

# Print the data sorted by the number of awards
grouped_data.sort_values('awards_proportion')
# Out:
#                                                                          award_id_piid  \
# awarding_agency_abbr awarding_agency_name
# DOC                  DEPARTMENT OF COMMERCE (DOC)                                    1
# DOI                  DEPARTMENT OF THE INTERIOR (DOI)                                1
# USDA                 DEPARTMENT OF AGRICULTURE (USDA)                                1
# DHS                  DEPARTMENT OF HOMELAND SECURITY (DHS)                           2
# DOJ                  DEPARTMENT OF JUSTICE (DOJ)                                     3
# GSA                  GENERAL SERVICES ADMINISTRATION (GSA)                           4
# VA                   DEPARTMENT OF VETERANS AFFAIRS (VA)                             4
# HHS                  DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)                  16
# NASA                 NATIONAL AERONAUTICS AND SPACE ADMINISTRATION (...             44
# DOD                  DEPARTMENT OF DEFENSE (DOD)                                   358
#
#                                                                          total_dollars_obligated  \
# awarding_agency_abbr awarding_agency_name
# DOC                  DEPARTMENT OF COMMERCE (DOC)                                  28473075.4900
# DOI                  DEPARTMENT OF THE INTERIOR (DOI)                                199655.7600
# USDA                 DEPARTMENT OF AGRICULTURE (USDA)                                248091.2200
# DHS                  DEPARTMENT OF HOMELAND SECURITY (DHS)                          1571321.1700
# DOJ                  DEPARTMENT OF JUSTICE (DOJ)                                      78535.1000
# GSA                  GENERAL SERVICES ADMINISTRATION (GSA)                       2053157545.6600
# VA                   DEPARTMENT OF VETERANS AFFAIRS (VA)                            1735127.2000
# HHS                  DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)                151231405.2100
# NASA                 NATIONAL AERONAUTICS AND SPACE ADMINISTRATION (...         14295043444.7400
# DOD                  DEPARTMENT OF DEFENSE (DOD)                               458721481384.2405
#
#                                                                          dollar_obligated_proportion  \
# awarding_agency_abbr awarding_agency_name
# DOC                  DEPARTMENT OF COMMERCE (DOC)                                             0.0001
# DOI                  DEPARTMENT OF THE INTERIOR (DOI)                                         0.0000
# USDA                 DEPARTMENT OF AGRICULTURE (USDA)                                         0.0000
# DHS                  DEPARTMENT OF HOMELAND SECURITY (DHS)                                    0.0000
# DOJ                  DEPARTMENT OF JUSTICE (DOJ)                                              0.0000
# GSA                  GENERAL SERVICES ADMINISTRATION (GSA)                                    0.0043
# VA                   DEPARTMENT OF VETERANS AFFAIRS (VA)                                      0.0000
# HHS                  DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)                            0.0003
# NASA                 NATIONAL AERONAUTICS AND SPACE ADMINISTRATION (...                       0.0301
# DOD                  DEPARTMENT OF DEFENSE (DOD)                                              0.9652
#
#                                                                          awards_proportion
# awarding_agency_abbr awarding_agency_name
# DOC                  DEPARTMENT OF COMMERCE (DOC)                                   0.0023
# DOI                  DEPARTMENT OF THE INTERIOR (DOI)                               0.0023
# USDA                 DEPARTMENT OF AGRICULTURE (USDA)                               0.0023
# DHS                  DEPARTMENT OF HOMELAND SECURITY (DHS)                          0.0046
# DOJ                  DEPARTMENT OF JUSTICE (DOJ)                                    0.0069
# GSA                  GENERAL SERVICES ADMINISTRATION (GSA)                          0.0092
# VA                   DEPARTMENT OF VETERANS AFFAIRS (VA)                            0.0092
# HHS                  DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)                  0.0369
# NASA                 NATIONAL AERONAUTICS AND SPACE ADMINISTRATION (...             0.1014
# DOD                  DEPARTMENT OF DEFENSE (DOD)                                    0.8249

# %% [markdown]
# Notice that we essentially coiped and pasted the grouping and column calculation code from earlier in the cell above. Anytime you notice yourself doing so, look into defining a function. This is done in the following code block.

# %%
def custom_grouper(df, agg_dict, agg_columns):
    '''
    This function groups the provided DataFrame, df, by the columns
    specified in the agg_columns argument. The aggregations specified
    in the agg_dict dictionary are applied. Also, each column in the 
    agg_dict is used to create a proportion column. The grouped data
    is returned as a DataFrame sorted by the keys of the agg_dict
    dictionary, in the order they are specified, i.e., first key
    has a higher sort priority than the second, etc...
    
    NOTE: This function assumes that no column specified in the agg_dict
    has more than one aggregation applied!
    '''
    
    df = df.groupby(agg_columns).agg(agg_dict)

    for key in agg_dict.keys():
        df[f'{key}_proportion'] = (df[key]/df[key].sum())
        
    df = df.sort_values([key for key in agg_dict.keys()])

    return df

# %% [markdown]
# The following code block shows how we can use the newly defined function.

# %%
agg_dict = {'total_dollars_obligated': 'sum', 'award_id_piid':'nunique'}

agg_columns = ['awarding_agency_abbr', 'awarding_agency_name']

custom_grouper(naics_data, agg_dict, agg_columns)
# Out:
#                                                                          total_dollars_obligated  \
# awarding_agency_abbr awarding_agency_name
# DOJ                  DEPARTMENT OF JUSTICE (DOJ)                                      78535.1000
# DOI                  DEPARTMENT OF THE INTERIOR (DOI)                                199655.7600
# USDA                 DEPARTMENT OF AGRICULTURE (USDA)                                248091.2200
# DHS                  DEPARTMENT OF HOMELAND SECURITY (DHS)                          1571321.1700
# VA                   DEPARTMENT OF VETERANS AFFAIRS (VA)                            1735127.2000
# DOC                  DEPARTMENT OF COMMERCE (DOC)                                  28473075.4900
# HHS                  DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)                151231405.2100
# GSA                  GENERAL SERVICES ADMINISTRATION (GSA)                       2053157545.6600
# NASA                 NATIONAL AERONAUTICS AND SPACE ADMINISTRATION (...         14295043444.7400
# DOD                  DEPARTMENT OF DEFENSE (DOD)                               458721481384.2405
#
#                                                                          award_id_piid  \
# awarding_agency_abbr awarding_agency_name
# DOJ                  DEPARTMENT OF JUSTICE (DOJ)                                     3
# DOI                  DEPARTMENT OF THE INTERIOR (DOI)                                1
# USDA                 DEPARTMENT OF AGRICULTURE (USDA)                                1
# DHS                  DEPARTMENT OF HOMELAND SECURITY (DHS)                           2
# VA                   DEPARTMENT OF VETERANS AFFAIRS (VA)                             4
# DOC                  DEPARTMENT OF COMMERCE (DOC)                                    1
# HHS                  DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)                  16
# GSA                  GENERAL SERVICES ADMINISTRATION (GSA)                           4
# NASA                 NATIONAL AERONAUTICS AND SPACE ADMINISTRATION (...             44
# DOD                  DEPARTMENT OF DEFENSE (DOD)                                   358
#
#                                                                          total_dollars_obligated_proportion  \
# awarding_agency_abbr awarding_agency_name
# DOJ                  DEPARTMENT OF JUSTICE (DOJ)                                                     0.0000
# DOI                  DEPARTMENT OF THE INTERIOR (DOI)                                                0.0000
# USDA                 DEPARTMENT OF AGRICULTURE (USDA)                                                0.0000
# DHS                  DEPARTMENT OF HOMELAND SECURITY (DHS)                                           0.0000
# VA                   DEPARTMENT OF VETERANS AFFAIRS (VA)                                             0.0000
# DOC                  DEPARTMENT OF COMMERCE (DOC)                                                    0.0001
# HHS                  DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)                                   0.0003
# GSA                  GENERAL SERVICES ADMINISTRATION (GSA)                                           0.0043
# NASA                 NATIONAL AERONAUTICS AND SPACE ADMINISTRATION (...                              0.0301
# DOD                  DEPARTMENT OF DEFENSE (DOD)                                                     0.9652
#
#                                                                          award_id_piid_proportion
# awarding_agency_abbr awarding_agency_name
# DOJ                  DEPARTMENT OF JUSTICE (DOJ)                                           0.0069
# DOI                  DEPARTMENT OF THE INTERIOR (DOI)                                      0.0023
# USDA                 DEPARTMENT OF AGRICULTURE (USDA)                                      0.0023
# DHS                  DEPARTMENT OF HOMELAND SECURITY (DHS)                                 0.0046
# VA                   DEPARTMENT OF VETERANS AFFAIRS (VA)                                   0.0092
# DOC                  DEPARTMENT OF COMMERCE (DOC)                                          0.0023
# HHS                  DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)                         0.0369
# GSA                  GENERAL SERVICES ADMINISTRATION (GSA)                                 0.0092
# NASA                 NATIONAL AERONAUTICS AND SPACE ADMINISTRATION (...                    0.1014
# DOD                  DEPARTMENT OF DEFENSE (DOD)                                           0.8249

# %% [markdown]
# # Who are we purchasing from?
#
# The following code block determines the total amount and number of agencies assciated with transactions, grouped by the recipient.

# %%
agg_dict = {'awarding_agency_abbr': 'nunique',
            'total_dollars_obligated': 'sum'}

agg_columns = ['recipient_duns', 'recipient_name']

custom_grouper(naics_data, agg_dict, agg_columns)
# Out:
#                                                     awarding_agency_abbr  \
# recipient_duns recipient_name
# 800218005      WEATHERS, FRANK                                         1
# 16444445       HIGH ALTITUDE RESEARCH CORPORATION                      1
# 126236301      AXIOS SOLUTIONS, INC.                                   1
# 66470972       AUBURN UNIVERSITY                                       1
# 832641059      SHAPEFIDELITY, INC.                                     1
# ...                                                                  ...
# 839422763      ANALYTICAL SERVICES, INC.                               3
# 75458455       DYNETICS, INC.                                          3
# 102067378      COLSA CORPORATION                                       3
# 63690705       UNIVERSITY OF ALABAMA AT BIRMINGHAM                     4
# 31994218       RADIANCE TECHNOLOGIES, INC.                             4
#
#                                                     total_dollars_obligated  \
# recipient_duns recipient_name
# 800218005      WEATHERS, FRANK                                    2700.0000
# 16444445       HIGH ALTITUDE RESEARCH CORPORATION                 5850.0000
# 126236301      AXIOS SOLUTIONS, INC.                             33950.0000
# 66470972       AUBURN UNIVERSITY                                300000.0000
# 832641059      SHAPEFIDELITY, INC.                              586376.0000
# ...                                                                     ...
# 839422763      ANALYTICAL SERVICES, INC.                     869276340.2700
# 75458455       DYNETICS, INC.                               1822471852.7500
# 102067378      COLSA CORPORATION                           16008130740.1600
# 63690705       UNIVERSITY OF ALABAMA AT BIRMINGHAM           417735107.4000
# 31994218       RADIANCE TECHNOLOGIES, INC.                  2003166344.4300
#
#                                                     awarding_agency_abbr_proportion  \
# recipient_duns recipient_name
# 800218005      WEATHERS, FRANK                                               0.0086
# 16444445       HIGH ALTITUDE RESEARCH CORPORATION                            0.0086
# 126236301      AXIOS SOLUTIONS, INC.                                         0.0086
# 66470972       AUBURN UNIVERSITY                                             0.0086
# 832641059      SHAPEFIDELITY, INC.                                           0.0086
# ...                                                                             ...
# 839422763      ANALYTICAL SERVICES, INC.                                     0.0259
# 75458455       DYNETICS, INC.                                                0.0259
# 102067378      COLSA CORPORATION                                             0.0259
# 63690705       UNIVERSITY OF ALABAMA AT BIRMINGHAM                           0.0345
# 31994218       RADIANCE TECHNOLOGIES, INC.                                   0.0345
#
#                                                     total_dollars_obligated_proportion
# recipient_duns recipient_name
# 800218005      WEATHERS, FRANK                                                  0.0000
# 16444445       HIGH ALTITUDE RESEARCH CORPORATION                               0.0000
# 126236301      AXIOS SOLUTIONS, INC.                                            0.0000
# 66470972       AUBURN UNIVERSITY                                                0.0000
# 832641059      SHAPEFIDELITY, INC.                                              0.0000
# ...                                                                                ...
# 839422763      ANALYTICAL SERVICES, INC.                                        0.0018
# 75458455       DYNETICS, INC.                                                   0.0038
# 102067378      COLSA CORPORATION                                                0.0337
# 63690705       UNIVERSITY OF ALABAMA AT BIRMINGHAM                              0.0009
# 31994218       RADIANCE TECHNOLOGIES, INC.                                      0.0042
#
# [92 rows x 4 columns]

# %% [markdown]
# # How are we purchasing?
#
# The following code block determines the total amount associated with transactions, grouped by the contract pricing type.

# %%
agg_dict = {'total_dollars_obligated': 'sum'}

agg_columns = ['type_of_contract_pricing', 
               'type_of_contract_pricing_code']

custom_grouper(naics_data, agg_dict, agg_columns)
# Out:
#                                                            total_dollars_obligated  \
# type_of_contract_pricing    type_of_contract_pricing_code
# FIXED PRICE LEVEL OF EFFORT B                                       311614493.7200
# LABOR HOURS                 Z                                      1532251481.6800
# COST NO FEE                 S                                      2055611834.4600
# COST PLUS AWARD FEE         R                                     15838529409.4000
# FIRM FIXED PRICE            J                                     15988743479.8000
# TIME AND MATERIALS          Y                                     36306117144.2999
# COST PLUS FIXED FEE         U                                     39160657809.2199
# COST PLUS INCENTIVE FEE     V                                    364059693933.2102
#
#                                                            total_dollars_obligated_proportion
# type_of_contract_pricing    type_of_contract_pricing_code
# FIXED PRICE LEVEL OF EFFORT B                                                          0.0007
# LABOR HOURS                 Z                                                          0.0032
# COST NO FEE                 S                                                          0.0043
# COST PLUS AWARD FEE         R                                                          0.0333
# FIRM FIXED PRICE            J                                                          0.0336
# TIME AND MATERIALS          Y                                                          0.0764
# COST PLUS FIXED FEE         U                                                          0.0824
# COST PLUS INCENTIVE FEE     V                                                          0.7660

# %% [markdown]
# The following code block determines the total amount associated with transactions, grouped by the solicitation procedures.

# %%
agg_dict = {'total_dollars_obligated': 'sum'}

agg_columns = ['extent_competed', 'solicitation_procedures']

custom_grouper(naics_data, agg_dict, agg_columns)
# Out:
#                                                                                                total_dollars_obligated  \
# extent_competed                                    solicitation_procedures
# NOT COMPETED UNDER SAP                             SIMPLIFIED ACQUISITION                                    2700.0000
# COMPETED UNDER SAP                                 SIMPLIFIED ACQUISITION                                 1154637.0500
# NOT AVAILABLE FOR COMPETITION                      ONLY ONE SOURCE                                        7602004.6100
# FULL AND OPEN COMPETITION AFTER EXCLUSION OF SO... TWO STEP                                              69647951.2000
# FULL AND OPEN COMPETITION                          BASIC RESEARCH                                       218146493.3600
# FULL AND OPEN COMPETITION AFTER EXCLUSION OF SO... SEALED BID                                           534993518.6400
# NOT COMPETED                                       ONLY ONE SOURCE                                     4877717257.9300
# FULL AND OPEN COMPETITION AFTER EXCLUSION OF SO... NEGOTIATED PROPOSAL/QUOTE                          10546859351.9500
#                                                    SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY         13445024687.3600
# FULL AND OPEN COMPETITION                          SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY         31526511066.4300
#                                                    NEGOTIATED PROPOSAL/QUOTE                         414025559917.2601
#
#                                                                                                total_dollars_obligated_proportion
# extent_competed                                    solicitation_procedures
# NOT COMPETED UNDER SAP                             SIMPLIFIED ACQUISITION                                                  0.0000
# COMPETED UNDER SAP                                 SIMPLIFIED ACQUISITION                                                  0.0000
# NOT AVAILABLE FOR COMPETITION                      ONLY ONE SOURCE                                                         0.0000
# FULL AND OPEN COMPETITION AFTER EXCLUSION OF SO... TWO STEP                                                                0.0001
# FULL AND OPEN COMPETITION                          BASIC RESEARCH                                                          0.0005
# FULL AND OPEN COMPETITION AFTER EXCLUSION OF SO... SEALED BID                                                              0.0011
# NOT COMPETED                                       ONLY ONE SOURCE                                                         0.0103
# FULL AND OPEN COMPETITION AFTER EXCLUSION OF SO... NEGOTIATED PROPOSAL/QUOTE                                               0.0222
#                                                    SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY                              0.0283
# FULL AND OPEN COMPETITION                          SUBJECT TO MULTIPLE AWARD FAIR OPPORTUNITY                              0.0663
#                                                    NEGOTIATED PROPOSAL/QUOTE                                               0.8712

# %% [markdown]
# # All together

# %%
def custom_grouper(df, agg_dict, agg_columns):
    
    df = df.groupby(agg_columns).agg(agg_dict)

    for key in agg_dict.keys():
        df[f'{key}_proportion'] = (df[key]/df[key].sum())
        
    df = df.sort_values([key for key in agg_dict.keys()])

    return df

# %%
run_cell = False

if run_cell:

    filepath = 'AL_FY2019.csv'

    data = pd.read_csv(filepath)
    mask = data['total_dollars_obligated'] <= 0
    data = data[~mask]

    agg_dict = {'award_id_piid':'nunique', 'total_dollars_obligated': 'sum'}
    agg_columns = ['naics_code', 'naics_description']

    grouped_data = data.groupby(agg_columns).agg(agg_dict)

    top_naics_codes = grouped_data.nlargest(10, columns = ['total_dollars_obligated']).index.tolist()

    for naics_code, naics_description in top_naics_codes:
        with pd.ExcelWriter(f'outputs/{int(naics_code)}_output.xlsx') as writer:  
            mask = data['naics_code'] == naics_code
            naics_data = data[mask]

            # Who is buying
            agg_dict = {'total_dollars_obligated': 'sum', 
                        'award_id_piid':'nunique'}
            agg_columns = ['awarding_agency_abbr', 'awarding_agency_name']
            custom_grouper(naics_data, agg_dict, agg_columns).to_excel(writer, 'Buying Agencies')


            # Who are we buying from
            agg_dict = {'awarding_agency_abbr': 'nunique',
                        'total_dollars_obligated': 'sum'}
            agg_columns = ['recipient_duns', 'recipient_name']

            custom_grouper(naics_data, agg_dict, agg_columns).to_excel(writer, 'Recipients')


            # how are we buying - contracts
            agg_dict = {'total_dollars_obligated': 'sum'}
            agg_columns = ['type_of_contract_pricing', 'type_of_contract_pricing_code']
            custom_grouper(naics_data, agg_dict, agg_columns).to_excel(writer, 'Contract Types')

            # how are we buying - solicitation
            agg_dict = {'total_dollars_obligated': 'sum'}
            agg_columns = ['extent_competed', 'solicitation_procedures']
            custom_grouper(naics_data, agg_dict, agg_columns).to_excel(writer, 'Solicitation Type')
